# %%
import folium
import pandas as pd

# %%
register_df = pd.read_csv('1877-official-register.csv')
print(register_df.sample(5))
register_df.dtypes
# Out:
#            Name State                  Department  \
# 660       Boise    ID         Treasury Department
# 97     Santa Fe    NM  Department of the Interior
# 234  Marysville    CA                    Judicial
# 501     Velasco    TX         Treasury Department
# 354      Eugene    OR                    Judicial
#
#                                           Type  People   Latitude   Longitude
# 660  Internal Revenue_Storekeepers and Gaugers       1  43.618710 -116.214607
# 97               General Land Office Registers       1  35.686975 -105.937799
# 234                               Commissioner       1  39.145725 -121.591355
# 501                            Customs Service       1  28.961914  -95.360495
# 354                               Commissioner       1  44.052069 -123.086754
# Name           object
# State          object
# Department     object
# Type           object
# People          int64
# Latitude      float64
# Longitude     float64
# dtype: object

# %%
register_df.sample(5)
# Out:
#               Name State                  Department  \
# 329     Algondones    NM                    Judicial
# 831    Fort Benton    MT              War Department
# 541         Merced    CA         Treasury Department
# 739        Bismark    ND              War Department
# 190  Yakama Agency    WA  Department of the Interior
#
#                                    Type  People   Latitude   Longitude
# 329                        Commissioner       1  35.380593 -106.479193
# 831                             Outpost      28  47.819444 -110.669722
# 541   Internal Revenue_Deputy Collector       1  37.302163 -120.482968
# 739  Quartermasters Department At Large       5  46.808327 -100.783739
# 190            Office of Indian Affairs      13  46.233333 -120.821944

# %%
us_map_empty = folium.Map(location=[38.7946, -98.5348], zoom_start=3)
us_map_empty
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9444f4e1faa30bf2cdb839eef5dcd91f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9444f4e1faa30bf2cdb839eef5dcd91f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9444f4e1faa30bf2cdb839eef5dcd91f = L.map(
#                 &quot;map_9444f4e1faa30bf2cdb839eef5dcd91f&quot;,
#                 {
#                     center: [38.7946, -98.5348],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 3,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1e28f382feac290a2deeb143331cfccc = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1e28f382feac290a2deeb143331cfccc.addTo(map_9444f4e1faa30bf2cdb839eef5dcd91f);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
def create_empty_map():
    return folium.Map(location=[38.7946, -98.5348], zoom_start=3)

us_map = create_empty_map()
us_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3f418b85f6cdd5d3fce4aa0f359b0b94 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3f418b85f6cdd5d3fce4aa0f359b0b94&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3f418b85f6cdd5d3fce4aa0f359b0b94 = L.map(
#                 &quot;map_3f418b85f6cdd5d3fce4aa0f359b0b94&quot;,
#                 {
#                     center: [38.7946, -98.5348],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 3,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_84f01ef3ace7bd28abc9edbdd5e6f284 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_84f01ef3ace7bd28abc9edbdd5e6f284.addTo(map_3f418b85f6cdd5d3fce4aa0f359b0b94);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
def reg_create_map_markers(row, map_name):
    folium.CircleMarker(location=[row['Latitude'], row['Longitude']], 
                       radius=row['People']/100, 
                        popup=folium.Popup(f"Location: {row['Name']}", max_width=200),
                       tooltip=f"Government Agency: {row['Department']} <br> Employees: {row['People']}").add_to(map_name)

# %%
#create a base empty map
us_map = create_empty_map()

#generate a random row of data
sample_row = register_df.sample(1)

#use our function on the random row
reg_create_map_markers(sample_row, us_map)

#display the map
us_map
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/folium/utilities.py:101: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   float(coord)
# /opt/anaconda3/lib/python3.12/site-packages/folium/utilities.py:107: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   if math.isnan(float(coord)):
# /opt/anaconda3/lib/python3.12/site-packages/folium/utilities.py:109: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   return [float(x) for x in coords]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/4y/l2xhtfxs2msgkp6_82yhlvv40000gn/T/ipykernel_13745/456948447.py in ?()
#       4 #generate a random row of data
#       5 sample_row = register_df.sample(1)
#       6
#       7 #use our function on the random row
# ----> 8 reg_create_map_markers(sample_row, us_map)
#       9
#      10 #display the map
#      11 us_map
#
# /var/folders/4y/l2xhtfxs2msgkp6_82yhlvv40000gn/T/ipykernel_13745/569265203.py in ?(row, map_name)
#       1 def reg_create_map_markers(row, map_name):
# ----> 2     folium.CircleMarker(location=[row['Latitude'], row['Longitude']],
#       3                        radius=row['People'],
#       4                         popup=folium.Popup(f"Location: {row['Name']}", max_width=200),
#       5                        tooltip=f"Government Agency: {row['Department']} <br> Employees: {row['People']}").add_to(map_name)
#
# /opt/anaconda3/lib/python3.12/site-packages/folium/vector_layers.py in ?(self, location, radius, popup, tooltip, **kwargs)
#     385         **kwargs: TypePathOptions,
#     386     ):
#     387         super().__init__(location, popup=popup, tooltip=tooltip)
#     388         self._name = "CircleMarker"
# --> 389         self.options = path_options(line=False, radius=radius, **kwargs)
#
# /opt/anaconda3/lib/python3.12/site-packages/folium/vector_layers.py in ?(line, radius, **kwargs)
#      84         extra_options = {
#      85             "smoothFactor": kwargs.pop("smoothFactor", 1.0),
#      86             "noClip": kwargs.pop("noClip", False),
#      87         }
# ---> 88     if radius:
#      89         extra_options.update({"radius": radius})
#      90
#      91     color = kwargs.pop("color", "#3388ff")
#
# /opt/anaconda3/lib/python3.12/site-packages/pandas/core/generic.py in ?(self)
#    1575     @final
#    1576     def __nonzero__(self) -> NoReturn:
# -> 1577         raise ValueError(
#    1578             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1579             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1580         )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
us_map = create_empty_map()

register_df.apply(
    reg_create_map_markers, 
    map_name=us_map, 
    axis='columns' 
)

us_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6f4b97a19fb6098daad4657f01cf2c17 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6f4b97a19fb6098daad4657f01cf2c17&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6f4b97a19fb6098daad4657f01cf2c17 = L.map(
#                 &quot;map_6f4b97a19fb6098daad4657f01cf2c17&quot;,
#                 {
#                     center: [38.7946, -98.5348],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 3,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_94678ef0c31dc314222166cd0edec923 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_94678ef0c31dc314222166cd0edec923.addTo(map_6f4b97a19fb6098daad4657f01cf2c17);
#
#
#             var circle_marker_296c71a5ba8fc58f95248f48001770f4 = L.circleMarker(
#                 [34.5400242, -112.468503],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 0.01, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_6f4b97a19fb6098daad4657f01cf2c17);
#
#
#         var popup_c8640c8483cc1e366e9aefb723468db5 = L.popup({
#   &quot;maxWidth&quot;: 200,
# });
#
#
#
#                 var html_9973c154e75bab7a03f6f05dfda65ece = $(`&lt;div id=&quot;html_9973c154e75bab7a03f6f05dfda65ece&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Location: Prescott&lt;/div&gt;`)[0];
#                 popup_c8640c8483cc1e366e9aefb723468db5.setContent(html_9973c154e75bab7a03f6f05dfda65ece);
#
#
#
#         circle_marker_296c71a5ba8fc58f95248f48001770f4.bindPopup(popup_c8640c8483cc1e366e9aefb723468db5)
#         ;
#
#
#
#
#             circle_marker_296c71a5ba8fc58f95248f48001770f4.bindTooltip(
#                 `&lt;div&gt;
#                      Government Agency: Department of the Interior &lt;br&gt; Employees: 1
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_ff4dc32928bdee643b5b5d3ba8dfd464 = L.circleMarker(
#                 [33.0314508, -111.387343],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 0.01, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_6f4b97a19fb6098daad4657f01cf2c17);
#
#
#         var popup_f9afb231a47c5c53724451fcc536b9f1 = L.popup({
#   &quot;maxWidth&quot;: 200,
# });
#
#
#
#                 var html_6157bdf0c2a116c82910a9b9f4ec483b = $(`&lt;div id=&quot;html_6157bdf0c2a116c82910a9b9f4ec483b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Location: Florence&lt;/div&gt;`)[0];
#                 popup_f9afb231a47c5c53724451fcc536b9f1.setContent(html_6157bdf0c2a116c82910a9b9f4ec483b);
#
#
#
#         circle_marker_ff4dc32928bdee643b5b5d3ba8dfd464.bindPopup(popup_f9afb231a47c5c53724451fcc536b9f1)
#         ;
#
#
#
#
#             circle_marker_ff4dc32928bdee643b5b5d3ba8dfd464.bindTooltip(
#                 `&lt;div&gt;
#                      Government Agency: Department of the Interior &lt;br&gt; Employees: 1
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_f0759fecf65d980b959666c0415e0b45 = L.circleMarker(
#                 [37.7749295, -122.419416],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 0.01, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_6f4b97a19fb6098daad4657f01cf2c17);
#
#
#         var popup_6da601751c1e8cde9c667c4c54a7eb67 = L.popup({
#   &quot;maxWidth&quot;: 200,
# });
#
#
#
#                 var html_fbf13a21a330a9db5e8e6a505f745867 = $(`&lt;div id=&quot;html_fbf13a21a330a9db5e8e6a505f745867&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;

# %%
register_df = register_df.sort_values(by='People', ascending=False)
register_df.head(10)
# Out:
#                       Name State      Department      Type  People   Latitude  \
# 875             Fort Clark    TX  War Department   Outpost     881  29.305833
# 858              Fort Sill    OK  War Department   Outpost     548  34.704167
# 884             Fort Brown    TX  War Department   Outpost     470  25.898333
# 895        Fort DA Russell    WY  War Department   Outpost     465  41.166389
# 823       Fort Leavenworth    KS  War Department   Outpost     441  39.355000
# 894           Fort Laramie    WY  War Department   Outpost     431  42.209167
# 822               Lewiston    ID  War Department     Other     427  46.399010
# 830             Fort Ellis    MT  War Department   Outpost     394  45.654444
# 845          Camp Robinson    NE  War Department   Outpost     391  42.668889
# 834  Tongue River Barracks    MT  War Department  Barracks     388  46.409282
#
#       Longitude
# 875 -100.408056
# 858  -98.508333
# 884  -97.492222
# 895 -104.862778
# 823  -94.921111
# 894 -104.535833
# 822 -117.004303
# 830 -110.976389
# 845 -103.467222
# 834 -105.866077

# %%
register_df.groupby('State').sum()['People'].sort_values(ascending=False)
# Out:
# State
# TX    3643
# WY    1646
# MT    1447
# AZ    1303
# NE    1296
# CA    1212
# OK    1107
# KS     990
# SD     930
# NM     892
# ND     857
# ID     621
# OR     322
# WA     311
# CO     289
# UT     262
# NV     187
# BC       1
# Name: People, dtype: int64

# %%
register_df.groupby('Department').sum()['People'].sort_values(ascending=False)
# Out:
# Department
# War Department                14940
# Treasury Department            1080
# Department of the Interior      891
# Judicial                        405
# Name: People, dtype: int64

# %%
register_df.groupby('State').count()['Name'].sort_values(ascending=False)
# Out:
# State
# CA    167
# TX    138
# KS     69
# OR     62
# NE     61
# WA     55
# MT     47
# AZ     42
# NM     41
# CO     39
# SD     37
# WY     34
# NV     25
# ID     25
# ND     22
# UT     21
# OK     17
# BC      1
# Name: Name, dtype: int64
